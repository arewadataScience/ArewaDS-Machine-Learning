# %% [markdown]
# # Introduction to Pandas
# **Author:** Lukman J Aliyu
# **Date:** 2025-05-24
#
#  Arewa Data Science Academy

# %% [markdown]
# ## Welcome!
# - **Topic:** Introduction to Pandas
# - **Duration:** 1 hour
# - **Audience:** Beginner to intermediate Python users

# %% [markdown]
# ## Objectives
# By the end of this session, you will:
# - Understand the relationship between Pandas and NumPy
# - Learn how to create and load DataFrames
# - Perform essential DataFrame operations
# - Visualize data with Pandas

# %% [markdown]
# ## Why Pandas?
# - Built on top of NumPy
# - Provides powerful `DataFrame` and `Series` structures
# - Intuitive data manipulation
# - Supports I/O from CSV, Excel, SQL, and more
# - Commonly used in data science, finance, and research

# %% [markdown]
# ## Installing Pandas

# %%
#!pip install pandas

# %% [markdown]
# ## Importing Pandas and NumPy

# %%
# import both we mostly use both together
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating a Series using NumPy

# %%
ser = pd.Series(np.random.rand(7))
ser
# Out:
# 0    0.749292
# 1    0.486284
# 2    0.829937
# 3    0.644836
# 4    0.659624
# 5    0.075816
# 6    0.748787
# dtype: float64

# %% [markdown]
# ## Creating a DataFrame from NumPy

# %%
data = np.random.randn(5, 3)
df = pd.DataFrame(data, columns=["A", "B", "C"])
df
# Out:
#           A         B         C
# 0  0.098677  0.001656  0.150050
# 1  1.305392  1.247778 -0.765055
# 2 -1.440192 -0.786442 -0.061879
# 3  1.041525  1.828024  0.243250
# 4  0.384150  0.704149 -0.545897

# %% [markdown]
# ## Creating a DataFrame from Dictionary

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Diana"],
    "Age": [24, 27, 22, 32],
    "City": ["Lagos", "Abuja", "Kano", "Ibadan"]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age    City
# 0    Alice   24   Lagos
# 1      Bob   27   Abuja
# 2  Charlie   22    Kano
# 3    Diana   32  Ibadan

# %% [markdown]
# ## Reading a CSV File

# %%
# df = pd.read_csv("data.csv")
# df.head()

# %% [markdown]
# ## Simulating a DataFrame for Exploration

# %%
df = pd.DataFrame({
    "student_id": np.arange(1, 6),
    "name": ["Ali", "Bola", "Chi", "Dayo", "Ella"],
    "math": np.random.randint(60, 100, size=5),
    "english": np.random.randint(50, 95, size=5),
    "science": np.random.randint(55, 100, size=5)
})
df
# Out:
#    student_id  name  math  english  science
# 0           1   Ali    89       61       57
# 1           2  Bola    64       66       88
# 2           3   Chi    86       86       69
# 3           4  Dayo    68       68       84
# 4           5  Ella    92       78       92

# %% [markdown]
# ## Accessing Columns and Rows

# %%
print(df["math"])
print(df.loc[0])
print(df.iloc[1:4])
# Out:
# 0    89
# 1    64
# 2    86
# 3    68
# 4    92
# Name: math, dtype: int64
# student_id      1
# name          Ali
# math           89
# english        61
# science        57
# Name: 0, dtype: object
#    student_id  name  math  english  science
# 1           2  Bola    64       66       88
# 2           3   Chi    86       86       69
# 3           4  Dayo    68       68       84

# %% [markdown]
# ## Basic Statistics

# %%
print(df.describe())
print(df.mean(numeric_only=True))
print(df["english"].max())
# Out:
#        student_id       math    english    science
# count    5.000000   5.000000   5.000000   5.000000
# mean     3.000000  79.800000  71.800000  78.000000
# std      1.581139  12.853015  10.059821  14.611639
# min      1.000000  64.000000  61.000000  57.000000
# 25%      2.000000  68.000000  66.000000  69.000000
# 50%      3.000000  86.000000  68.000000  84.000000
# 75%      4.000000  89.000000  78.000000  88.000000
# max      5.000000  92.000000  86.000000  92.000000
# student_id     3.0
# math          79.8
# english       71.8
# science       78.0
# dtype: float64
# 86

# %% [markdown]
# ## Filtering Data

# %%
print(df[df["math"] > 80])
print(df[(df["math"] > 80) & (df["english"] > 70)])
# Out:
#    student_id  name  math  english  science
# 0           1   Ali    89       61       57
# 2           3   Chi    86       86       69
# 4           5  Ella    92       78       92
#    student_id  name  math  english  science
# 2           3   Chi    86       86       69
# 4           5  Ella    92       78       92

# %% [markdown]
# ## Adding and Dropping Columns

# %%
df["total"] = df["math"] + df["english"] + df["science"]
df.drop("student_id", axis=1, inplace=True)
df
# Out:
#    name  math  english  science  total
# 0   Ali    89       61       57    207
# 1  Bola    64       66       88    218
# 2   Chi    86       86       69    241
# 3  Dayo    68       68       84    220
# 4  Ella    92       78       92    262

# %% [markdown]
# ## Sorting and Grouping

# %%
print(df.sort_values("total", ascending=False))
print(df.groupby("name")["math"].mean())
# Out:
#    name  math  english  science  total
# 4  Ella    92       78       92    262
# 2   Chi    86       86       69    241
# 3  Dayo    68       68       84    220
# 1  Bola    64       66       88    218
# 0   Ali    89       61       57    207
# name
# Ali     89.0
# Bola    64.0
# Chi     86.0
# Dayo    68.0
# Ella    92.0
# Name: math, dtype: float64

# %% [markdown]
# ## Plotting with Pandas

# %%
import matplotlib.pyplot as plt

df.set_index("name")[["math", "english", "science"]].plot(kind="bar")
plt.title("Scores by Subject")
plt.ylabel("Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
# - Pandas builds on NumPy for flexible tabular data handling
# - DataFrames make data manipulation intuitive
# - Use filtering, grouping, and plotting for quick insights

# %% [markdown]
# ## Try it Yourself!
# - Create your own DataFrame
# - Explore with filters and plots
# - Practice `groupby`, `mean`, and `plot` functions

# %% [markdown]
# ## Questions?
# Let's clarify concepts or try more examples live!

# %% [markdown]
# ## Thank You
# - [Pandas Documentation](https://pandas.pydata.org/)
# - Keep practicing and analyzing data!
