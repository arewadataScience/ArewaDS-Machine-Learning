# %% [markdown]
# # Distribution of Data
#
#
# - Distribution provides insights into the overall shape and characteristics of the data, such as its central tendency (mean, median), variability (range, standard deviation), and the presence of any outliers.
#
#
# - In simple terms, the distribution of data tells you how the values in your dataset are arranged. It shows you where most of the data points fall, how spread out they are, and whether there are any unusual values (outliers).
#
#
#
# ### Key Points:
#
# - **Central Tendency:** This refers to the "center" of the data, often measured by the mean (average), median (middle value), or mode (most frequent value).
#
# - **Variability:** This describes how much the data varies or spreads out. Common measures include range (difference between the highest and lowest values), variance, and standard deviation.
#
#
# - **Shape of Distribution:** This refers to the overall pattern of the data, which can be symmetrical (like a bell curve), skewed (leaning to one side), or uniform (evenly spread out).
#
# - **Outliers:** These are data points that are significantly different from the rest of the data. They can affect the overall analysis and may indicate special cases or errors in data collection.
#
# ### When to Use Distribution Analysis:
#
# - **When you want to understand the overall pattern of your data:** Distribution analysis helps you see how values are spread out, which can reveal trends or patterns.
#
#
# - **When you need to identify outliers:** By examining the distribution, you can spot unusual values that may need further investigation.
#
#
# - **When comparing different groups:** Distribution analysis allows you to compare how different datasets behave, such as comparing test scores between two classes or sales figures across different regions.

# %% [markdown]
# ### Examples of Distribution Analysis
#
# - **Customer Age Distribution:** Analyzing the ages of customers who purchased a product can help businesses understand their target audience better.
#
#
# - **Student Test Scores:** Examining the distribution of test scores in a class can reveal how well students performed and whether there are any outliers who scored significantly higher or lower than the rest.
#
# - **Sales Data:** Analyzing the distribution of sales figures over a period can help identify trends, seasonal patterns, or unusual spikes in sales.
#
# - **Employee Salaries:** Understanding the distribution of salaries within a company can help identify pay equity issues or areas where salary adjustments may be needed.
#
#
# ### **Common Chart Types and Easy Examples:**
#
# The most commonly used plots for distribution are:
#
# - Histogram
#
# - Box Plot (Box-and-Whisker Plot)
#
# - Violin Plot
#
# - Density Plot (Kernel Density Estimate)
#
# - ECDF (Empirical Cumulative Distribution Function)

# %% [markdown]
# A histogram divides data into bins (intervals) and counts how many values fall into each bin.
#
# Interpretation:
# This histogram shows our data is bell-shaped, meaning it's normally distributed with most values centered around 50.
#
# 🧠 Why it matters: Helps identify data symmetry, skewness, and multimodal patterns

# %% [markdown]
# ## Histogram — Student Test Scores
#
# **Dataset**: Simulated test scores of 200 students, with most scores between 65–85.
#
# This simulates a normal distribution of academic performance in a classroom.

# %% [markdown]
# ### Tough Subject
#
# - Right-skewed distribution
#
# - Scenario: A tough subject where most students score low, few excel

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

scores_tough_subject = np.random.beta(a=1, b=4, size=200) * 100  # scale to 0–100

plt.figure()
plt.hist(scores_tough_subject, bins=15, edgecolor='black')
plt.title("Student Scores (Right-Skewed): Tough Subject")
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Easy Subject
#
# - Left-skewed distribution
#
# - Scenario: An easy subject or generous grading where most students score high

# %%
scores_easy_subject = np.random.beta(a=5, b=1.5, size=200) * 100

plt.figure()
plt.hist(scores_easy_subject, bins=15, edgecolor='black')
plt.title("Student Scores (Left-Skewed): Easy Subject")
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

# %% [markdown]
# # Bimodal Distribution
# - Two peaks in the data
# - A subject with two student groups: prepared vs. unprepared

# %%
scores_mixed_ability = np.concatenate([
    np.random.normal(loc=50, scale=8, size=100),   # less prepared students
    np.random.normal(loc=85, scale=5, size=100)    # well-prepared students
])
scores_mixed_ability = np.clip(scores_mixed_ability, 0, 100)

plt.figure()
plt.hist(scores_mixed_ability, bins=15, edgecolor='black')
plt.title("Student Scores (Bimodal): Mixed-Ability Class")
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Box Plot: A Simple Summary of Data Distribution

# %% [markdown]
# Let’s say you’re a school principal and you just got the test scores for 100 students. You want to:
#
#
# - Quickly summarize the overall performance
#
# - See how spread out the scores are
#
# - Check for extremely high or low scores
#
# - Compare this class to other classes
#
# - A histogram could help—but it:
#
# Depends on bin size
#
# - Can’t show you exact medians or quartiles
#
# - Is harder to compare across multiple groups
#
# ✅ This is where a box plot shines — it's a compact, powerful summary!

# %% [markdown]
# 📘 What Does a Box Plot Show?
#
# A box plot gives you five important numbers:
#
#
# | Statistic       | Meaning                                                       |
# | --------------- | ------------------------------------------------------------- |
# | **Min**         | The lowest non-outlier score                                  |
# | **Q1**          | The 25th percentile (bottom 25% cutoff)                       |
# | **Median (Q2)** | The middle score (50th percentile)                            |
# | **Q3**          | The 75th percentile (top 25% cutoff)                          |
# | **Max**         | The highest non-outlier score                                 |
# | **Outliers**    | Dots beyond whiskers – students who scored unusually high/low |

# %% [markdown]
# ### Example 1: Box Plot — Student Exam Scores
#
# You're a teacher who just finished grading 100 final exam papers. You want to:
#
# - Summarize the class performance
#
# - Find the middle score (median)
#
# - Detect any very high or very low scores (outliers)
#
# - Quickly compare this class to others later

# %% [markdown]
# Why Not Histogram?
#
# - A histogram shows how many students got scores in each range, but:
#
# - It's hard to quickly identify the median
#
# - Outliers aren’t always obvious
#
# - Comparing multiple histograms gets messy

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

# Simulate exam scores: most students around 70-85
scores = np.random.normal(loc=75, scale=10, size=100)
scores[:5] = np.random.uniform(30, 45, size=5)   # Add a few low-score outliers
scores = np.clip(scores, 0, 100)

scores
# Out:
# array([42.10657793, 35.81790966, 42.95312782, 41.20682464, 38.34360351,
#        51.98461303, 92.44811764, 67.38793099, 78.19039096, 72.50629625,
#        89.62107937, 54.39859291, 71.77582796, 71.15945645, 86.33769442,
#        64.00108733, 73.27571792, 66.22141582, 75.42213747, 80.82815214,
#        63.99380823, 86.4472371 , 84.01590721, 80.02494339, 84.00855949,
#        68.16272141, 73.77109774, 65.64230566, 72.3211192 , 80.30355467,
#        68.08339248, 71.03246473, 68.128273  , 66.54794359, 68.28753869,
#        74.87335401, 63.82689651, 77.34415698, 91.59802177, 82.42044161,
#        73.08164448, 66.12371036, 67.52841706, 91.92454601, 75.50807755,
#        68.63004353, 76.90915485, 96.00255136, 76.20158952, 81.1720311 ,
#        78.0017032 , 71.47750154, 63.57481802, 71.50657278, 72.91105767,
#        80.86623191, 83.38983414, 84.31102081, 77.85587325, 83.85141164,
#        67.45602059, 87.52868155, 80.1292982 , 72.01907165, 79.88518147,
# ...

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(scores, vert=False)
plt.title("Box Plot: Final Exam Scores (100 Students)")
plt.xlabel("Score")
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretation:
#
# - The box shows most students scored between ~68 and 82.
#
# - The line inside the box (median) is around 75 — typical performance.
#
# - The left dots are students who may have failed — possible intervention needed.

# %% [markdown]
# ## Example 2: Box Plot — July Temperatures in a City
#
# You're analyzing weather data for a warm city. You want to:
#
# - Summarize the July heat
#
# - Detect unusual hot days (heatwaves)
#
# - Provide a report for public safety planning

# %%
np.random.seed(42)

# Simulate daily July temperatures (~30°C typical)
temperatures = np.random.normal(loc=30, scale=4, size=100)

# Insert a few heatwave days
temperatures[:5] = np.random.uniform(40, 45, size=5)
temperatures
# Simulate daily July temperatures with a few heatwave days
# Out:
# array([42.08705502, 41.11053905, 40.59932684, 41.68807586, 44.71454852,
#        29.06345217, 36.31685126, 33.06973892, 28.12210246, 32.17024017,
#        28.14632923, 28.13708099, 30.96784909, 22.34687902, 23.10032867,
#        27.75084988, 25.94867552, 31.25698933, 26.3679037 , 24.35078519,
#        35.86259508, 29.0968948 , 30.27011282, 24.30100726, 27.8224691 ,
#        30.44369036, 25.39602569, 31.50279207, 27.59744524, 28.833225  ,
#        27.59317355, 37.40911274, 29.9460111 , 25.76915628, 33.29017965,
#        25.1166254 , 30.83545438, 22.1613195 , 24.6872558 , 30.78744494,
#        32.95386632, 30.68547312, 29.53740687, 28.79558522, 24.08591204,
#        27.12062317, 28.15744492, 34.2284889 , 31.37447316, 22.94783938,
#        31.29633588, 28.45967088, 27.292312  , 32.44670516, 34.12399809,
#        33.72512048, 26.64312991, 28.7631505 , 31.32505373, 33.90218051,
#        28.08330305, 29.25736409, 25.5746601 , 25.2151735 , 33.25010329,
# ...

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(temperatures, vert=False)
plt.title("Box Plot: July Temperatures in City")
plt.xlabel("Temperature (°C)")
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretation:
#
# - Most July days stayed between ~27–33°C.
#
# - The median line is around 30°C — typical summer day.
#
# - The dots to the right (above 40°C) show extreme heat events.
#
# - A box plot here helps you monitor climate trends and plan health advisories.

# %% [markdown]
# # Bird

# %%
birds = pd.read_csv('../../data/birds.csv')
birds.head()
#print(len(birds.Order.unique().tolist()), birds.Order.unique().tolist())
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.plot(kind='scatter',x='MaxLength',y='Order',figsize=(12,8))

plt.title('Max Length per Order')
plt.ylabel('Order')
plt.xlabel('Max Length')

plt.show()

# %%
birds['MaxBodyMass'].plot(kind = 'hist', figsize = (12,12))
plt.show()

# %%
birds['MinBodyMass'].plot(kind = 'hist', bins = 30, figsize = (12,12))
plt.show()

# %%
filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 500)]
print(len(birds), len(filteredBirds))
filteredBirds['MaxBodyMass'].plot(kind = 'hist',bins = 40,figsize = (12,12))
plt.show()
# Out:
# 443 319

# %%
x = filteredBirds['MaxBodyMass']
y = filteredBirds['MaxLength']

fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(x, y)

# %%
cs = filteredBirds.ConservationStatus.unique().tolist()
flb = []
for c in cs:
  flb.append(filteredBirds.loc[filteredBirds.ConservationStatus=='{c}', 'MinWingspan'])

# %%
x1 = filteredBirds.loc[filteredBirds.ConservationStatus=='EX', 'MinWingspan']
x2 = filteredBirds.loc[filteredBirds.ConservationStatus=='CR', 'MinWingspan']
x3 = filteredBirds.loc[filteredBirds.ConservationStatus=='EN', 'MinWingspan']
x4 = filteredBirds.loc[filteredBirds.ConservationStatus=='NT', 'MinWingspan']
x5 = filteredBirds.loc[filteredBirds.ConservationStatus=='VU', 'MinWingspan']
x6 = filteredBirds.loc[filteredBirds.ConservationStatus=='LC', 'MinWingspan']

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='red', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')
plt.hist(x3, **kwargs, color='yellow', label='Endangered')
plt.hist(x4, **kwargs, color='green', label='Near Threatened')
plt.hist(x5, **kwargs, color='blue', label='Vulnerable')
plt.hist(x6, **kwargs, color='gray', label='Least Concern')

plt.gca().set(title='Conservation Status', ylabel='Min Wingspan')
plt.legend();

# %%
sns.kdeplot(filteredBirds['MinWingspan'])
plt.show()

# %%
sns.kdeplot(filteredBirds['MaxBodyMass'])
plt.show()

# %%
sns.kdeplot(filteredBirds['MaxBodyMass'], bw_adjust=.1)
plt.show()

# %%
sns.kdeplot(
   data=filteredBirds, x="MaxBodyMass", hue="Order",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)

# %%
sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# Out:
# /var/folders/v3/3dkg22g1169bpykn3jssbyph0000gn/T/ipykernel_53795/49960699.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# /var/folders/v3/3dkg22g1169bpykn3jssbyph0000gn/T/ipykernel_53795/49960699.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# /var/folders/v3/3dkg22g1169bpykn3jssbyph0000gn/T/ipykernel_53795/49960699.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredBirds, x="MinLength", y="MaxLength", hue="ConservationStatus")
# <Axes: xlabel='MinLength', ylabel='MaxLength'>
