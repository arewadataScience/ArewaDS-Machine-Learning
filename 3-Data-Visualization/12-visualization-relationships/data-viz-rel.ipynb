# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
honey = pd.read_csv('../../data/honey.csv')
honey.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
hn = honey[honey['state']=='AR']
print(len(hn))
hn
# Out:
# 15
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 2      AR  53000.0           65  3445000.0  1688000.0        0.59  2033000.0
# 45     AR  52000.0           89  4628000.0  2592000.0        0.53  2453000.0
# 88     AR  52000.0           93  4836000.0  3337000.0        0.57  2757000.0
# 131    AR  50000.0           98  4900000.0  1617000.0        0.65  3185000.0
# 175    AR  45000.0           88  3960000.0   871000.0        1.26  4990000.0
# 219    AR  40000.0           75  3000000.0   810000.0        1.26  3780000.0
# 263    AR  40000.0           57  2280000.0   388000.0        0.87  1984000.0
# 304    AR  36000.0           69  2484000.0   571000.0        0.97  2409000.0
# 345    AR  32000.0           76  2432000.0   730000.0        0.89  2164000.0
# 386    AR  28000.0           80  2240000.0   672000.0        0.95  2128000.0
# 427    AR  28000.0           75  2100000.0   525000.0        1.35  2835000.0
# 468    AR  24000.0           57  1368000.0   301000.0        1.42  1943000.0
# 508    AR  25000.0           60  1500000.0   360000.0        1.47  2205000.0
# 548    AR  22000.0           64  1408000.0   239000.0        1.62  2281000.0
# 588    AR  25000.0           63  1575000.0   189000.0        1.98  3119000.0
#
#      year
# 2    1998
# 45   1999
# 88   2000
# 131  2001
# 175  2002
# 219  2003
# 263  2004
# 304  2005
# 345  2006
# 386  2007
# 427  2008
# 468  2009
# 508  2010
# 548  2011
# 588  2012

# %%
sns.relplot(x="priceperlb", y="state", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="priceperlb", y="state", hue="year", palette="YlOrBr", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="priceperlb", y="state", size="year", data=honey, height=15, aspect=.5);

# %%
sns.relplot(x="year", y="priceperlb", kind="line", data=hn);

# %%
sns.relplot(x="year", y="totalprod", kind="line", data=honey);

# %%
sns.relplot(
    data=honey, 
    x="yieldpercol", y="numcol",
    col="year", 
    col_wrap=3,
    kind="line"
)

# %%
fig, ax = plt.subplots(figsize=(12,6))
lineplot = sns.lineplot(x=honey['year'], y=honey['numcol'], data=honey, 
                        label = 'Number of bee colonies', legend=False)
sns.despine()
plt.ylabel('# colonies')
plt.title('Honey Production Year over Year');

ax2 = ax.twinx()
lineplot2 = sns.lineplot(x=honey['year'], y=honey['yieldpercol'], ax=ax2, color="r", 
                         label ='Yield per colony', legend=False) 
sns.despine(right=False)
plt.ylabel('colony yield')
ax.figure.legend();
